# %%
# Importando bibliotecas

import pandas as pd

# %%
url = "https://pt.wikipedia.org/wiki/Copa_do_Mundo_FIFA_de_2022"

# %%
tabelas = pd.read_html(url)

# %%
tabela_desejada = tabelas[6]

# %%
tabela_desejada
# Out:
#    Confederação                   Árbitro (36)            Assistente (69)  \
# 0           AFC      QAT Abdulrahman Al-Jassim         QAT Taleb Al Marri
# 1           AFC                AUS Chris Beath       AUS Anton Shchetinin
# 2           AFC            IRN Alireza Faghani  IRN Mohammadreza Mansouri
# 3           AFC                    CHN Ma Ning              CHN Shi Xiang
# 4           AFC  UAE Mohammed Abdulla Mohammed      UAE Mohamed Alhammadi
# 5           AFC          JPN Yoshimi Yamashita                        NaN
# 6           CAF             GAM Bakary Gassama           CMR Elvis Noupue
# 7           CAF           ALG Mustapha Ghorbal      ALG Abdelhak Etchiali
# 8           CAF               RSA Victor Gomes         RSA Zakhele Siwela
# 9           CAF           SEN Maguette N'Diaye         SEN Djibril Camara
# 10          CAF              ZAM Janny Sikazwe      ANG Jerson dos Santos
# 11          CAF          RWA Salima Mukansanga                        NaN
# ...

# %%
df = tabela_desejada

# %%
dados = df[['Confederação', 'Árbitro (36)', 'Assistente (69)']]

# %%
dados
# Out:
#    Confederação                   Árbitro (36)            Assistente (69)
# 0           AFC      QAT Abdulrahman Al-Jassim         QAT Taleb Al Marri
# 1           AFC                AUS Chris Beath       AUS Anton Shchetinin
# 2           AFC            IRN Alireza Faghani  IRN Mohammadreza Mansouri
# 3           AFC                    CHN Ma Ning              CHN Shi Xiang
# 4           AFC  UAE Mohammed Abdulla Mohammed      UAE Mohamed Alhammadi
# 5           AFC          JPN Yoshimi Yamashita                        NaN
# 6           CAF             GAM Bakary Gassama           CMR Elvis Noupue
# 7           CAF           ALG Mustapha Ghorbal      ALG Abdelhak Etchiali
# 8           CAF               RSA Victor Gomes         RSA Zakhele Siwela
# 9           CAF           SEN Maguette N'Diaye         SEN Djibril Camara
# 10          CAF              ZAM Janny Sikazwe      ANG Jerson dos Santos
# 11          CAF          RWA Salima Mukansanga                        NaN
# ...
